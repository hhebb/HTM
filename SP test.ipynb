# %% [markdown]
# ---
# # Spatial Pooler & Encoder 통합 테스트 및 시각화
#
# - encoding data sparsity - 25 %
# - overlap threshold      - 20 %
# - input range            - 0~30
# - epoch                  - 15
#
# ---
# 가까운 입력일수록 SDR 을 일정비율 공유한다.</br>
# range 가 넓을수록 유사도 측정하기가 편리함
#
# ---

# %%
import numpy as np
import random
import time

import nbimporter
import SP3
import Encoder

# %%
encoder = Encoder.ScalarEncoder(out_size=100, max_val=30, w=25)
sp = SP3.SpatialPooler(encoder.out_size, columns=512, perm_conn=.6, minOver=encoder.w/5, potential_rate=0.8)

# %%
for epoch in range(5):
    for dat in range(30):
        sp.compute_SDR(encoder.encode(dat), debug=True)

# %%
sp.viz_sparsity_period()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="12b005b9-931f-4f15-a637-63c5d0dfe81d">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="cf74c9a2-7671-4547-802c-2256515631a7"></div>

# %%
sp.viz_NetState()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2982b8dc-9265-42dc-99fc-863eac9782de">Loading BokehJS ...</span>
#     </div>
# > desired active column count : 10 <
#   <div class="bk-root" id="24f50348-2a94-4142-81e9-dbb9ff08fb72"></div>
# boost factor
#
# -> 평균 : 1.0526041666666668, 표준편차 : 0.2390613652841625
#   <div class="bk-root" id="66131457-16d5-4080-a30a-84ea434d45ca"></div>
# active duty
#
# -> 평균 : 0.026250000000000002, 표준편차 : 0.016051133570215183
#   <div class="bk-root" id="67e36cad-694d-4df1-9cb6-53b9c237fc21"></div>
# overlap duty
#
# -> 평균 : 0.9025911458333333, 표준편차 : 0.14238959365043874

# %%
sp.consistency(encoder.encode(5), 10)
# Out:
# 오류 : 0.0

# %%
sp.compute_SDR(encoder.encode(16), False)
sdr1 = sp.getActiveColumns()
sp.compute_SDR(encoder.encode(17), False)
sdr2 = sp.getActiveColumns()

sp.similarity(sdr1, sdr2)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="413ed3fa-cb2c-48b5-870e-d39ae9f87ee0">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="80eaaff6-7a11-480e-b1c5-2412c6ae2109"></div>
# 유사도 : 0.09090909090909091
# [ 17  26  89 114 246 388 414 421 466 475 496]
# [ 11  31 131 278 282 309 375 380 381 396 414 504]

# %%
for i in range(30):
    sp.compute_SDR(encoder.encode(i), learn=False)
    sdr1 = sp.getActiveColumns()
    sp.compute_SDR(encoder.encode(i+1), learn=False)
    sdr2 = sp.getActiveColumns()
    
    sp.similarity(sdr1, sdr2, True)
    print('')
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="83b7143c-e61d-4205-8b72-6fbf661af045">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="9588f805-ea70-40ea-b167-601ce29fd141"></div>
# 유사도 : 0.625
# [ 59  78 133 139 148 149 188 334 367 397 408 435 436 449 452 475]
# [ 59  78 119 148 149 235 281 334 397 435 436 439 449 475 481]
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="7bdcb041-a689-48a9-9358-dcec0329030c">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="a0eab92f-253c-495b-a1e3-5a1496a0888d"></div>
# 유사도 : 0.3333333333333333
# [ 59  78 119 148 149 235 281 334 397 435 436 439 449 475 481]
# [ 48  65  78 149 187 196 235 393 397 432 481]
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="47fba23d-3dc1-4c72-abb2-6689e2033a12">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="b3849689-ab1c-49d1-b89e-5c09b185e67e"></div>
# 유사도 : 0.45454545454545453
# [ 48  65  78 149 187 196 235 393 397 432 481]
# [ 65 149 173 196 246 284 292 308 367 429 432 452 481]
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="7f766ecf-5f26-473a-9ad4-47ebf091271e">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="8ba8d95a-adab-4911-9930-993706fed71a"></div>
# 유사도 : 0.23076923076923078
# [ 65 149 173 196 246 284 292 308 367 429 432 452 481]
# [112 129 136 148 158 213 246 308 377 452 499]
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id