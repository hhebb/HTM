# %% [markdown]
# ---
# # Spatial Pooler & Encoder 통합 테스트 및 시각화
#
# ---

# %%
import numpy as np
import random
import time

import nbimporter
import SP3
import Encoder
# Out:
# Importing Jupyter notebook from SP3.ipynb
# Importing Jupyter notebook from Encoder.ipynb

# %%
encoder = Encoder.ScalarEncoder(out_size=200, max_val=10, w=40)
sp = SP3.SpatialPooler(encoder.out_size, columns=512, perm_conn=.6, minOver=encoder.w/7, potential_rate=0.9)
#data = [4,2,10,3,8,1,7,9,5]

# %%
for epoch in range(40):
    for dat in range(10):
        sp.compute_SDR(encoder.encode(dat), debug=False)

# %%
sp.viz_sparsity_period()

# %%
sp.viz_NetState()

# %%
sp.viz_activeCol()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="abb650df-5076-4438-afd5-51427628fde6">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="3d667762-c1ac-4bcd-a229-757a7d527bba"></div>
# active columns : [6, 36, 51, 64, 89, 196, 218, 403, 404, 411, 436, 442]
# count : 12

# %%
sp.consistency(encoder.encode(5), 10)
# Out:
# 오류 : 0.0

# %%
sp.compute_SDR(encoder.encode(1), False)
sdr1 = sp.getActiveColumns()
sp.compute_SDR(encoder.encode(2), False)
sdr2 = sp.getActiveColumns()

sp.similarity(sdr1, sdr2)

# %%
sp.viz_connected_synapses(332)
