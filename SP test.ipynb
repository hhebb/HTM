# %% [markdown]
# ---
# # Spatial Pooler & Encoder 통합 테스트 및 시각화
#
# ---

# %%
import numpy as np
import random
import time

import nbimporter
import SP3
import Encoder
# Out:
# Importing Jupyter notebook from SP3.ipynb
# Importing Jupyter notebook from Encoder.ipynb

# %%
encoder = Encoder.ScalarEncoder(out_size=100, max_val=10, w=30)
sp = SP3.SpatialPooler(encoder.out_size, columns=512, perm_conn=.7, minOver=5, potential_rate=0.9)
data = [4,2,10,3,8,1,7,9,5]

# %%
for epoch in range(30):
    for dat in range(10):
        sp.compute_SDR(encoder.encode(dat), debug=True)

# %%
sp.viz_sparsity_period()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="aa94ff28-2ff8-448a-8a4b-544419e0c5f0">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="e0fb33ab-4c60-4032-a092-bcbd960cd632"></div>

# %%
sp.viz_NetState()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="c9d119dc-ac66-4330-8ba8-391d9edb7b8c">Loading BokehJS ...</span>
#     </div>
# > desired active column count : 10 <
#   <div class="bk-root" id="ce4efb70-28c3-4111-bb49-a9beaf169c7b"></div>
# boost factor
#
# -> 평균 : 1.2505371093750002, 표준편차 : 0.4619305558919482
#   <div class="bk-root" id="eea2e9df-470d-4e27-a6c9-b7e595b788dd"></div>
# active duty
#
# -> 평균 : 0.023759765625000002, 표준편차 : 0.01888945282611618
#   <div class="bk-root" id="c6ef70a5-303e-4e3f-8c6c-c9b784bea450"></div>
# overlap duty
#
# -> 평균 : 0.93892578125, 표준편차 : 0.12640197520342453

# %%
sp.viz_activeCol()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="85a772ae-93e9-4ce3-a879-6c5794234323">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="8d5374b0-fbaa-4ace-b0d3-4624846d9b2f"></div>
# active columns : [82, 165, 200, 224, 232, 245, 249, 252, 283, 360, 387, 432, 437]
# count : 13

# %%
sp.consistency(encoder.encode(5), 10)
# Out:
# 오류 : 0.0

# %%
sp.compute_SDR(encoder.encode(2), False)
sdr1 = sp.getActiveColumns()
sp.compute_SDR(encoder.encode(1), False)
sdr2 = sp.getActiveColumns()

sp.similarity(sdr1, sdr2)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="10c9bf6c-2cc7-401f-bdf6-4b59fce586f8">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="8357476d-d66b-46c5-bdad-5f6640075ada"></div>
# 유사도 : 0.1111111111111111
# [25, 69, 73, 94, 141, 186, 256, 384, 403, 406]
# [18, 25, 116, 378, 397, 402, 403, 465, 486, 508]
