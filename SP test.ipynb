# %% [markdown]
# ---
# # Spatial Pooler & Encoder 통합 테스트 및 시각화
#
# - encoding data sparsity - 25 %
# - overlap threshold      - 20 %
# - input range            - 0~30
# - epoch                  - 15
#
# ---
# 가까운 입력일수록 SDR 을 일정비율 공유한다.</br>
# range 가 넓을수록 유사도 측정하기가 편리함
#
# ---

# %%
import numpy as np
import random
import time

import nbimporter
import SP3
import Encoder
# Out:
# Importing Jupyter notebook from SP3.ipynb
# Importing Jupyter notebook from Encoder.ipynb

# %%
encoder = Encoder.ScalarEncoder(out_size=100, max_val=30, w=25)
sp = SP3.SpatialPooler(encoder.out_size, columns=512, perm_conn=.6, minOver=encoder.w/5, potential_rate=0.9)

# %%
for epoch in range(4):
    for dat in range(30):
        sp.compute_SDR(encoder.encode(dat), debug=False)

# %%
sp.viz_sparsity_period()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="eb5fd5b4-e29c-4bd0-8e4e-8ecff8f574b5">Loading BokehJS ...</span>
#     </div>
# C:\Anaconda\lib\site-packages\bokeh\models\sources.py:110: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x', 200), ('y', 0)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))
#   <div class="bk-root" id="e6da18b5-25e6-483c-b708-dbccc93e4975"></div>

# %%
sp.viz_NetState()

# %%
sp.viz_activeCol()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="c3ab4603-3f09-4ef6-bd19-ab676ae1a367">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="a28946f0-ac9a-4af3-9190-f5fe74be11e8"></div>
# active columns : [30, 103, 175, 190, 198, 279, 308, 354, 407, 454]
# count : 10

# %%
sp.consistency(encoder.encode(5), 10)
# Out:
# 오류 : 0.0

# %%
sp.compute_SDR(encoder.encode(15), False)
sdr1 = sp.getActiveColumns()
sp.compute_SDR(encoder.encode(17), False)
sdr2 = sp.getActiveColumns()

sp.similarity(sdr1, sdr2)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="cc165be3-bf06-48a1-a5e3-48b74b07a586">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="f88a9619-bd70-4429-9df1-d08b4cb31caf"></div>
# 유사도 : 0.16666666666666666
# [29, 49, 95, 106, 163, 173, 200, 295, 339, 395]
# [29, 67, 95, 128, 173, 254, 266, 300, 358, 451, 485]

# %%
for i in range(30):
    sp.compute_SDR(encoder.encode(i), learn=False)
    sdr1 = sp.getActiveColumns()
    sp.compute_SDR(encoder.encode(i+3), learn=False)
    sdr2 = sp.getActiveColumns()
    
    sp.similarity(sdr1, sdr2, True)
    print('')
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2fda0f81-b92b-4a0e-a06d-0339176bfd1d">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="457e9800-008e-46e6-b9e1-7733232360d0"></div>
# 유사도 : 0.42105263157894735
# [ 14  25  51 156 168 171 184 212 245 259 284 288 290 298 301 332 351 431
#  445]
# [ 14  94 168 171 235 240 259 288 290 301 329 375 431]
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="0e02a69e-5e3b-41b3-9da3-6bf9eb9ef60e">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="899ab401-f176-407f-8606-1b5dc95b3bf7"></div>
# 유사도 : 0.4
# [ 14  25  46  51 156 171 227 259 288 290 298 301 329 332 351]
# [  1  14  94 171 240 259 288 301 329 378 449]
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="cc279b73-b9c5-4245-87d9-71f7c4718bf1">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="1bd1cc8e-2907-4f67-9784-457dcc01aceb"></div>
# 유사도 : 0.4
# [ 14  25  97 168 171 227 259 288 290 298 301 329 375 407 431]
# [ 57  70  94 171 240 259 288 301 324 329 354 375 449]
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="96736d78-9f65-40f5-b9e4-510129b8bc82">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="12784f9d-9d7d-4e5b-aef7-1419181faa6a"></div>
# 유사도 : 0.5384615384615384
# [ 14  94 168 171 235 240 259 288 290 301 329 375 431]
# [ 57  70  94 160 171 240 273 282 288 301 324 329 354 375 423 449]
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="7848df60-1ea5-4e68-9137-19f6a14b4d45">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="65cd915e-0a00-4cfa-878c-a7097c417676"></div>
# 유사도 : 0.45454545454545453
# [  1  14  94 171 240 259 288 301 329 378 449]
# [ 57 171 240 273 282 288 301 324 329 423]
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="88159878-aba0-4773-9000-5dee77af9c9c">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="f41b9999-1efd-41ee-947f-30f9cc15639d"></div>
# 유사도 : 0.5384615384615384
# [ 57  70  94 171 240 259 288 301 324 329 354 375 449]
# [ 26  57 171 178 273 288 301 329 375 407 423 449]
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="ec791044-3722-4fc8-9db0-2a7953cf967d">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="1ffa70d6-4404-44a7-b970-a207c8f56aa7"></div>
# 유사도 : 0.625
# [ 57  70  94 160 171 240 273 282 288 301 324 329 354 375 423 449]
# [  1  13  26  57 129 171 188 273 288 290 301 324 329 357 375 407 423 449]
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="51a2fc6b-dca6-46c1-81eb-8ac9cf2af5cf">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="affb69ef-e1a4-4c79-99a2-1713fafcd124"></div>
# 유사도 : 0.6
# [ 57 171 240 273 282 288 301 324 329 423]
# [ 57  68 140 171 188 288 290 301 329 375 386 423 439]
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="cee7646b-bf94-4a5c-959d-0cc93fb16f6c">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="04e62788-017e-4651-9325-d94686be81f3"></div>
# 유사도 : 0.5833333333333334
# [ 26  57 171 178 273 288 301 329 375 407 423 449]
# [ 13  57  68 171 188 230 241 259 288 301 319 329 386 413 423 439 449]
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="694aee75-6152-44ff-95de-c3fc68dc8df2">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="b789a96a-7705-45b0-89ae-3131ce1105e9"></div>
# 유사도 : 0.2222222222222222
# [  1  13  26  57 129 171 188 273 288 290 301 324 329 357 375 407 423 449]
# [ 27  57  68 168 230 259 301 319 329 386 407 439 443]
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="49e4a130-034f-4214-aab7-4eb203b54b2a">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="631993d0-5585-4d72-bcc7-1ace7760e05d"></div>
# 유사도 : 0.6923076923076923
# [ 57  68 140 171 188 288 290 301 329 375 386 423 439]
# [ 27  46  51  57  68 103 148 179 184 188 216 230 282 288 290 301 315 329
#  375 407 439 443 450 504 506]
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="014fc5f4-3667-4fb8-9a33-1377a8b9f968">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="c5120080-d1b5-4122-a4af-69af29604ed9"></div>
# 유사도 : 0.17647058823529413
# [ 13  57  68 171 188 230 241 259 288 301 319 329 386 413 423 439 449]
# [  5  51  68 184 255 290 301 329 418 450 460]
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="ab218534-fefc-49bc-931f-df4ae1e1d310">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="5ba939b4-bfaa-4eb6-b44e-c3531ddec722"></div>
# 유사도 : 0.6153846153846154
# [ 27  57  68 168 230 259 301 319 329 386 407 439 443]
# [  5  14  27  51  62  68 115 118 127 152 156 158 168 184 188 240 255 276
#  285 296 301 319 329 359 365 371 378 387 401 407 443 445 449 450 465]
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="cc016de0-b6e4-4546-a069-19388edd53ad">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="da3e73be-136c-427c-8bdc-3107f3420184"></div>
# 유사도 : 0.2
# [ 27  46  51  57  68 103 148 179 184 188 216 230 282 288 290 301 315 329
#  375 407 439 443 450 504 506]
# [  5  51 127 168 184 216 296 301 329 365 387 401 449 465]
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="3b75f462-6360-4267-a8c0-4b0bd4daf0d8">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="48dc409d-71f3-461a-9605-2f33b8c4511d"></div>
# 유사도 : 0.36363636363636365
# [  5  51  68 184 255 290 301 329 418 450 460]
# [ 26  51  62 103 115 118 168 184 203 296 301 329 431 449]
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="9ee0378c-79c7-4442-ba2e-fa498cc4a617">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="555fbbe0-7690-44c7-ade8-ad5c1ca5c19b"></div>
# 유사도 : 0.34285714285714286
# [  5  14  27  51  62  68 115 118 127 152 156 158 168 184 188 240 255 276
#  285 296 301 319 329 359 365 371 378 387 401 407 443 445 449 450 465]
# [ 26  39  51  68 103 118 168 188 216 240 282 296 301 329 425 438 443 445
#  449 463]
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="e9dc31ed-b64c-43d6-a3e2-81596f61bc4a">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="e8787d65-705f-413b-b1ee-4b3903c0a1a0"></div>
# 유사도 : 0.42857142857142855
# [  5  51 127 168 184 216 296 301 329 365 387 401 449 465]
# [ 26  51  68 156 238 282 285 296 301 319 378 401 431 438 446 449 452 463
#  465]
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="305107dc-19ad-4457-b640-044f288eac24">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="ffec8bc6-3152-4dad-ab74-dc25964672a7"></div>
# 유사도 : 0.42857142857142855
# [ 26  51  62 103 115 118 168 184 203 296 301 329 431 449]
# [ 25  26  51 115 156 238 282 301 329 449]
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="844fd3b4-5e72-4786-b32a-660d27fc369b">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="99a288c5-ae3a-4f30-95af-c8aa0f397a99"></div>
# 유사도 : 0.3
# [ 26  39  51  68 103 118 168 188 216 240 282 296 301 329 425 438 443 445
#  449 463]
# [ 26  51  75 115 156 227 240 282 301 342 370 390 449]
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="27a8be9c-564e-4e52-aecf-f63a1fd81503">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="95e89ed1-d9f5-47c2-afc1-a52ff9839b82"></div>
# 유사도 : 0.3157894736842105
# [ 26  51  68 156 238 282 285 296 301 319 378 401 431 438 446 449 452 463
#  465]
# [ 26  51 156 227 282 301 302 342 370 390 449]
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="728f0936-a8fc-4bca-adbe-6427cca9bcde">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="6748e0f0-dd82-4f3f-8c67-dc883b05d118"></div>
# 유사도 : 0.5
# [ 25  26  51 115 156 238 282 301 329 449]
# [ 26 140 156 227 282 301 320 324 342 354 370 449]
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="99718766-e4ff-49c1-ab72-4271bf6184c8">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="b5d25827-f1a8-4c41-a74e-08a71ade3583"></div>
# 유사도 : 0.6153846153846154
# [ 26  51  75 115 156 227 240 282 301 342 370 390 449]
# [ 26  98 156 227 259 282 288 301 324 342 354 370 441 446 449]
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="36aa6675-8b2c-4d02-a072-7098d06b1472">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="edc50a8a-afc4-4ef2-bc6b-e9435bc2bdd9"></div>
# 유사도 : 0.7272727272727273
# [ 26  51 156 227 282 301 302 342 370 390 449]
# [ 26  98 127 156 227 259 273 288 301 324 342 354 370 380 390 395 446 449
#  486]
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="c55259ab-9fc6-46e5-b870-4a19a10e5fc2">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="ea7abfa2-5076-4aa6-af05-61d01affd341"></div>
# 유사도 : 0.5833333333333334
# [ 26 140 156 227 282 301 320 324 342 354 370 449]
# [ 26  51  98 127 156 227 259 288 301 342 370 395 446 449 486]
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="b1c7fbd4-84e4-4802-bf95-629b53b80345">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="ed0396a4-32b9-4ae7-a230-71febea43aa2"></div>
# 유사도 : 0.6666666666666666
# [ 26  98 156 227 259 282 288 301 324 342 354 370 441 446 449]
# [ 26 140 156 227 282 301 320 324 342 354 370 449]
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="388bad66-7112-4bf9-968c-64fcb4aec2ec">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="52a4d429-af60-46e3-a5f4-b844198b1a63"></div>
# 유사도 : 0.42105263157894735
# [ 26  98 127 156 227 259 273 288 301 324 342 354 370 380 390 395 446 449
#  486]
# [ 26  51 115 156 168 227 282 301 310 329 342 370 390 438 449]
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="5b2ef807-4376-484f-a975-d4a6da769cd0">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="c4f7ce77-45a2-4ed8-ae63-e1b30b160ab5"></div>
# 유사도 : 0.5333333333333333
# [ 26  51  98 127 156 227 259 288 301 342 370 395 446 449 486]
# [ 26  51  75 115 156 227 240 282 301 342 370 390 449]
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="47929026-fffb-493c-a149-f86e5b42e941">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="cbc4ff61-4bf5-4bd9-acc2-2b3e2a15399b"></div>
# 유사도 : 0.5833333333333334
# [ 26 140 156 227 282 301 320 324 342 354 370 449]
# [ 26 115 156 240 282 301 324 329 342 438 449]
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="349fc139-2a8b-48fd-92c7-6fda5980c667">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="feada609-9e7f-45fe-b4bd-648d0fb41d03"></div>
# 유사도 : 0.6
# [ 26  51 115 156 168 227 282 301 310 329 342 370 390 438 449]
# [ 26 115 156 240 282 301 324 329 342 438 449]
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="02e88b7a-4dae-450c-bed6-f1595d9881d2">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="b606feb8-e5fc-44b4-9107-3e5d06f28a88"></div>
# 유사도 : 0.6153846153846154
# [ 26  51  75 115 156 227 240 282 301 342 370 390 449]
# [ 26 115 156 240 282 301 324 329 342 438 449]
