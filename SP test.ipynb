# %% [markdown]
# ---
# # Spatial Pooler & Encoder 통합 테스트 및 시각화
#
# - encoding data sparsity - 25 %
# - overlap threshold      - 20 %
# - input range            - 0~30
# - epoch                  - 15
#
# ---
# 가까운 입력일수록 SDR 을 일정비율 공유한다.
#
# ---

# %%
import numpy as np
import random
import time

import nbimporter
import SP3
import Encoder
# Out:
# Importing Jupyter notebook from SP3.ipynb
# Importing Jupyter notebook from Encoder.ipynb

# %%
encoder = Encoder.ScalarEncoder(out_size=100, max_val=30, w=25)
sp = SP3.SpatialPooler(encoder.out_size, columns=512, perm_conn=.6, minOver=encoder.w/5, potential_rate=0.9)

# %%
for epoch in range(15):
    for dat in range(30):
        sp.compute_SDR(encoder.encode(dat), debug=False)

# %%
sp.viz_sparsity_period()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="eb5fd5b4-e29c-4bd0-8e4e-8ecff8f574b5">Loading BokehJS ...</span>
#     </div>
# C:\Anaconda\lib\site-packages\bokeh\models\sources.py:110: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x', 200), ('y', 0)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))
#   <div class="bk-root" id="e6da18b5-25e6-483c-b708-dbccc93e4975"></div>

# %%
sp.viz_NetState()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="90f3cf8f-dfef-49b0-974d-a5aa8793e538">Loading BokehJS ...</span>
#     </div>
# > desired active column count : 10 <
#   <div class="bk-root" id="a6296b4b-e65b-4903-b24d-587aa34e3bc1"></div>
# boost factor
#
# -> 평균 : 1.140380859375, 표준편차 : 0.276556323138726
#   <div class="bk-root" id="0feccd6c-d66b-44fd-8d39-2d656b9a5554"></div>
# active duty
#
# -> 평균 : 0.021728515625000003, 표준편차 : 0.010197776993498674
#   <div class="bk-root" id="7cb9d757-e69a-4a2f-a4e1-06775d5060ed"></div>
# overlap duty
#
# -> 평균 : 0.94283203125, 표준편차 : 0.0982696341971874

# %%
sp.viz_activeCol()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="c3ab4603-3f09-4ef6-bd19-ab676ae1a367">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="a28946f0-ac9a-4af3-9190-f5fe74be11e8"></div>
# active columns : [30, 103, 175, 190, 198, 279, 308, 354, 407, 454]
# count : 10

# %%
sp.consistency(encoder.encode(5), 10)
# Out:
# 오류 : 0.0

# %%
sp.compute_SDR(encoder.encode(15), False)
sdr1 = sp.getActiveColumns()
sp.compute_SDR(encoder.encode(17), False)
sdr2 = sp.getActiveColumns()

sp.similarity(sdr1, sdr2)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="cc165be3-bf06-48a1-a5e3-48b74b07a586">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="f88a9619-bd70-4429-9df1-d08b4cb31caf"></div>
# 유사도 : 0.16666666666666666
# [29, 49, 95, 106, 163, 173, 200, 295, 339, 395]
# [29, 67, 95, 128, 173, 254, 266, 300, 358, 451, 485]

# %%
for i in range(30):
    sp.compute_SDR(encoder.encode(i), learn=False)
    sdr1 = sp.getActiveColumns()
    sp.compute_SDR(encoder.encode(i+3), learn=False)
    sdr2 = sp.getActiveColumns()
    
# [14, 21, 44, 82, 98, 144, 159, 193, 202, 252, 273, 293, 336, 380, 415]
# [26, 42, 62, 83, 89, 131, 144, 148, 159, 193, 293, 472]
#
# 유사도 : 0.1111111111111111
# [14, 82, 97, 99, 144, 159, 193, 206, 336, 505]
# [62, 89, 104, 133, 144, 193, 317, 468, 472, 476]
#
# 유사도 : 0.09090909090909091
# [44, 72, 82, 97, 144, 159, 181, 193, 288, 336, 403, 415, 469, 471]
# [20, 51, 57, 133, 159, 160, 193, 276, 293, 409]
#
# 유사도 : 0.1
# [26, 42, 62, 83, 89, 131, 144, 148, 159, 193, 293, 472]
# [20, 34, 51, 148, 174, 193, 276, 480, 484, 510]
#
# 유사도 : 0.0
# [62, 89, 104, 133, 144, 193, 317, 468, 472, 476]
# [52, 212, 251, 271, 321, 364, 366, 372, 466, 510]
#
# 유사도 : 0.0
# [20, 51, 57, 133, 159, 160, 193, 276, 293, 409]
# [27, 53, 123, 147, 151, 212, 238, 271, 354, 362, 466, 510]
#
# 유사도 : 0.05263157894736842
# [20, 34, 51, 148, 174, 193, 276, 480, 484, 510]
# [102, 207, 239, 349, 354, 355, 381, 417, 463, 510]
#
# 유사도 : 0.05263157894736842
# [52, 212, 251, 271, 321, 364, 366, 372, 466, 510]
# [5, 22, 102, 207, 305, 355, 379, 448, 508, 510]
#
# 유사도 : 0.08333333333333333
# [27, 53, 123, 147, 151, 212, 238, 271, 354, 362, 466, 510]
# [30, 52, 102, 111, 305, 344, 355, 362, 383, 393, 435, 448, 465, 510]
#
# 유사도 : 0.15
# [102, 207, 239, 349, 354, 355, 381, 417, 463, 510]
# [22, 52, 102, 111, 142, 305, 355, 390, 448, 465, 487, 509, 510]
#
# 유사도 : 0.25
# [5, 22, 102, 207, 305, 355, 379, 448, 508, 510]
# [102, 207, 239, 349, 354, 355, 381, 417, 463, 510]
#
# 유사도 : 0.08
# [30, 52, 102, 111, 305, 344, 355, 362, 383, 393, 435, 448, 465, 510]
# [18, 53, 134, 147, 151, 261, 281, 324, 354, 362, 377, 439, 510]
#
# 유사도 : 0.09523809523809523
# [22, 52, 102, 111, 142, 305, 355, 390, 448, 465, 487, 509, 510]
# [52, 212, 251, 271, 321, 364, 366, 372, 466, 510]
#
# 유사도 : 0.05
# [102, 207, 239, 349, 354, 355, 381, 417, 463, 510]
# [148, 160, 174, 212, 276, 283, 318, 466, 480, 484, 510]
#
# 유사도 : 0.043478260869565216
# [18, 53, 134, 147, 151, 261, 281, 324, 354, 362, 377, 439, 510]
# [148, 160, 174, 212, 276, 283, 318, 466, 480, 484, 510]
#
# 유사도 : 0.16666666666666666
# [52, 212, 251, 271, 321, 364, 366, 372, 466, 510]
# [148, 160, 174, 212, 276, 283, 318, 466, 480, 484, 510]
