# %% [markdown]
# ---
# # Spatial Pooler & Encoder 통합 테스트 및 시각화
#
# - encoding data sparsity - 25 %
# - overlap threshold      - 20 %
# - input range            - 0~30
# - epoch                  - 15
#
# ---
# 가까운 입력일수록 SDR 을 일정비율 공유한다.</br>
# range 가 넓을수록 유사도 측정하기가 편리함
#
# ---

# %%
import numpy as np
import random
import time

import nbimporter
import SP3
import Encoder

# %%
encoder = Encoder.ScalarEncoder(out_size=100, max_val=30, w=25)
sp = SP3.SpatialPooler(encoder.out_size, columns=512, perm_conn=.6, minOver=encoder.w/5, potential_rate=0.9)

# %%
for epoch in range(4):
    for dat in range(30):
        sp.compute_SDR(encoder.encode(dat), debug=True)

# %%
sp.viz_sparsity_period()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="95ce9361-0695-4fcd-bab4-28adfb5f6777">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="d6814d06-d8ad-4b04-98f5-232a3b04a0f2"></div>

# %%
sp.viz_NetState()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="0fe66d68-f933-40ea-bc00-a44ecb28f535">Loading BokehJS ...</span>
#     </div>
# > desired active column count : 10 <
#   <div class="bk-root" id="3d6716cf-51f7-460e-b964-348968a73777"></div>
# boost factor
#
# -> 평균 : 1.127197265625, 표준편차 : 0.2846561216110558
#   <div class="bk-root" id="64f907b7-9301-4476-a97b-64ae07d61393"></div>
# active duty
#
# -> 평균 : 0.022177734375, 표준편차 : 0.009960549739695262
#   <div class="bk-root" id="660dee51-cfd9-4a95-bee1-cac1df1723b5"></div>
# overlap duty
#
# -> 평균 : 0.939287109375, 표준편차 : 0.10227027223896389

# %%
sp.viz_activeCol()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="5fa7e3d7-9e78-4da1-bb5d-6de22041c551">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="7e764205-9d24-418b-ba46-e6009a0970eb"></div>
# active columns : [81, 232, 234, 265, 277, 334, 381, 382, 467, 483]
# count : 10

# %%
sp.consistency(encoder.encode(5), 10)
# Out:
# 오류 : 0.0

# %%
sp.compute_SDR(encoder.encode(15), False)
sdr1 = sp.getActiveColumns()
sp.compute_SDR(encoder.encode(17), False)
sdr2 = sp.getActiveColumns()

sp.similarity(sdr1, sdr2)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="78c0d96a-7149-4877-87fd-7c5cd387754a">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="52346df1-c754-48ac-947f-8754f305b2b2"></div>
# 유사도 : 0.0
# [ 21 121 137 197 206 284 297 315 318 377 415 454]
# [ 36  41 233 280 292 409 435 458 468 473]

# %%
for i in range(30):
    sp.compute_SDR(encoder.encode(i), learn=False)
    sdr1 = sp.getActiveColumns()
    sp.compute_SDR(encoder.encode(i+3), learn=False)
    sdr2 = sp.getActiveColumns()
    
    sp.similarity(sdr1, sdr2, True)
    print('')
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="7d478a62-7ad3-42e7-b4c5-9844fd98ef56">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="ad905d4a-8b49-433a-a24a-e46d760441d4"></div>
# 유사도 : 0.4
# [ 83 106 129 211 222 317 345 356 449 492]
# [ 38  44  46  83 106 129 146 151 203 301 317 346 371 430 472]
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="8f5b18c0-c780-42cd-9104-63a9aff7fd4e">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="3af245d9-efeb-4748-98ef-7b48fc2d4579"></div>
# 유사도 : 0.09090909090909091
# [ 44  82 106 222 317 345 348 356 394 449 495]
# [ 15  64 151 198 203 259 301 317 346 430]
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="b8ff5823-b219-4b5e-bd6b-ecb5694b9dee">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="11e7d1c3-51fd-4d6f-993d-8ea2f8b811e7"></div>
# 유사도 : 0.25
# [ 38  44  82  83 106 122 146 151 222 301 317 336 345 371 430 472]
# [ 15  64 151 161 165 198 203 301 317 430 497]
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="52ae70fa-c941-4e98-bf72-29e1e3807a08">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id